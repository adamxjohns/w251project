# %% [markdown]
# # Image Preporcessing

# %% [markdown]
# There are a few steps for image preprocessing so we can use them for training.
# 1. Image Extraction: Video recordings of a person will be extracted frame by frame and the frames will be saved as images for subsequent process
# 2. Face Alignment: The images extrated will go through face detection model to extract the faces with a predefined marginal space
# 3. Face Encoding: The headshots will be fed into the FaceNet model in order to get the embedding for the face. **Note: this preprocessing might be integrated into training if we are doing fine-tuning where we are adjusting the top layer of the FaceNet model.**

# %%
#impoart packages used for visulization in this notebook
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# ## 1. Image Extraction

# %%
# Import packages
import os
from os.path import isdir
from os.path import join

import cv2

# %% [markdown]
# **Set the arguments. When running the code as script, one will have to use argparse or similar package to feed to arguments into the script**

# %%
args = {
    # Set input directory
    # The names of the subdirectories will be the class labels
    "input_dir":"../face-recognition/data_final/videos",
    # Set output directory
    # The labels will be subdirectories 
    #     where extracted images are saved
    "output_dir":"../face-recognition/data_test2/images",
    "split_types":["train", "val", "test"],
    # Define how many frames to skip before extract each frame 
    "skip":100
}

# %% [markdown]
# **Extract frames and save as images**

# %%
for split in args["split_types"]:
    input_dir = join(args["input_dir"], split)
    subdirs = [subdir for subdir in os.listdir(input_dir) if isdir(join(input_dir,subdir))]
    # print(subdirs)
    for subdir in subdirs:
        output_subdir = join(args["output_dir"], split, subdir)
        if not os.path.exists(output_subdir):
            os.makedirs(output_subdir)
        for video in os.listdir(join(input_dir,subdir)):
            video_path = join(input_dir,subdir, video)
            vs = cv2.VideoCapture(video_path)
            read = 0
            saved = 0
            # loop over frames from the video file stream
            while True:
                # grab the frame from the file
                (grabbed, frame) = vs.read()
                # if the frame was not grabbed, then we have reached the end
                # of the stream
                if not grabbed:
                    break
                # increment the total number of frames read thus far
                read += 1
                # check to see if we should process this frame
                if read % args["skip"] != 0:
                    continue
                output_img_path = join(output_subdir,"{}.png".format(saved))
                cv2.imwrite(output_img_path, frame)
                saved += 1
                print("[INFO] saved {} to disk".format(output_img_path))
# Out:
# [INFO] saved ../face-recognition/data_test2/images/train/erik/0.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/1.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/2.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/3.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/4.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/5.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/6.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/7.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/8.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/9.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/10.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/11.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/12.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/13.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/14.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/15.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/16.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/17.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/18.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/19.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/20.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/21.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/22.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/23.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/24.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/erik/25.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/0.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/1.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/2.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/3.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/4.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/5.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/6.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/7.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/8.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/9.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/10.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/11.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/12.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/13.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/14.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/15.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/16.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/17.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/18.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/19.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/20.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/21.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/22.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/23.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/24.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/25.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/26.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/27.png to disk
# [INFO] saved ../face-recognition/data_test2/images/train/diana/28.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/erik/0.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/erik/1.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/erik/2.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/erik/3.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/0.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/1.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/2.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/3.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/4.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/5.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/6.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/7.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/8.png to disk
# [INFO] saved ../face-recognition/data_test2/images/val/diana/9.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/erik/0.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/erik/1.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/erik/2.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/erik/3.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/diana/0.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/diana/1.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/diana/2.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/diana/3.png to disk
# [INFO] saved ../face-recognition/data_test2/images/test/diana/4.png to disk

# %% [markdown]
# ## Face Alignment

# %% [markdown]
# Once we have a bunch of images, we can align the faces in those images and extract them, and again save them as images.

# %%
# Import packages
import os
from os.path import isdir
from os.path import join
import importlib

import numpy as np
import cv2

from src import detectors
# from common_resources.detectors import FaceDetector


importlib.reload(detectors)
FaceDetector = detectors.FaceDetector

# %% [markdown]
# We have a few options for face detections:
# 1. The detector in HW7
# 2. Open CV detector
#
# Build a wrapper so we can use them in the same way

# %%
args = {
    # Set input directory
    # The names of the subdirectories will be the class labels
    "input_dir":"data/images/",
    # Set output directory
    # The labels will be subdirectories 
    #     where extracted faces are saved
    "output_dir":"data/faces_hw7/",
    # Define the margin (extra space) for face alignment
    "margin":10,
    "split_types":["train", "val", "test"],
    # Define the face detector used and paramters
    # for OpenCV ("OPENCV", MODEL_FILE_PATH, scaleFactor, MinNeighbors)
    # for HW7 ("HW7", MODEL_FILE_PATH, DETECTION_THRESHOLD)
#     "detector": ("OPENCV", 
#                  "src/detector/haarcascade_frontalface_default.xml", 
#                  1.3, 
#                  5)
#     "detector": ("OPENCV", 
#                  "src/detector/haarcascade_frontalface_alt2.xml", 
#                  1.1, 
#                  3)
    "detector": ("HW7", 
                 "src/detectors/frozen_inference_graph_face.pb", 
                 0.7)
#     "detector": ("DLIB",)    
}

# %%
# dlib_face_detector = FaceDetector(args["detector"])
# hw7_face_detector = FaceDetector(("HW7", "detector/frozen_inference_graph_face.pb", 0.5))
# opencv_face_detector = FaceDetector(("OPENCV", "detector/haarcascade_frontalface_default.xml", 1.3, 5))

# %%
# for i in range(20):
#     # get sample images
#     image = cv2.imread(args["input_dir"] + f"/diana/{i}.png")
#     print(args["input_dir"])
#     fig = plt.figure()
#     ax = fig.add_subplot(1, 1, 1)

#     ax.imshow(image)
#     x,y,w,h = hw7_face_detector.detect_faces(image)[0]
#     print(x,y,w,h, w*h)
#     x,y,w,h = opencv_face_detector.detect_faces(image)[0]
#     print(x,y,w,h, w*h)
#     x,y,w,h = face_detector.detect_faces(image)[0]
#     print(x,y,w,h, w*h)
#     # display rectangle
#     patch = patches.Rectangle((x, y), w, h, color='g', alpha=0.3)
#     ax.add_patch(patch)

#     plt.show()

# %%
# Initialize the detector of choice
face_detector = FaceDetector(args["detector"])
margin = args["margin"]

for split in args["split_types"]:
    input_dir = join(args["input_dir"], split)
    subdirs = [subdir for subdir in os.listdir(input_dir) if isdir(join(input_dir,subdir))]
    
    for subdir in subdirs:
        output_subdir = join(args["output_dir"], split, subdir)
        if not os.path.exists(output_subdir):
            os.makedirs(output_subdir)
        saved = 0
        for file in os.listdir(join(input_dir, subdir)):
            image_path = join(input_dir, subdir, file)
            image = cv2.imread(image_path)

            faces = face_detector.detect_faces(image)
            for (x,y,w,h) in faces:
                x_start = max(0,x-margin//2)
                y_start = max(0,y-margin//2)
                x_end = min(image.shape[1], x+w+margin//2)
                y_end = min(image.shape[0], y+h+margin//2)
                cropped = image[y_start:y_end, x_start:x_end]
                # resize the image to 160x160 for FaceNet
                aligned = cv2.resize(cropped, (160, 160))
                output_img_path = join(output_subdir,"face_{}.png".format(saved))
                cv2.imwrite(output_img_path, aligned)
                saved += 1
                print("[INFO] saved {} to disk".format(output_img_path))
# Out:
# [INFO] saved data/faces_hw7/train/erik/face_0.png to disk
# [INFO] saved data/faces_hw7/train/erik/face
png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_114.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_115.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_116.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_117.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_118.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_119.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_120.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_121.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_122.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_123.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_124.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_125.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_126.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_127.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_128.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_129.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_130.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_131.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_132.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_133.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_134.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_135.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_136.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_137.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_138.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_139.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_140.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_141.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_142.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_143.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_144.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_145.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_146.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_147.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_148.png to disk
# [INFO] saved data/faces_hw7/test/unknown/face_149.png to disk

# %% [markdown]
# ## Face Encoding

# %% [markdown]
# Now that we have the faces extracted and aligned, we could encode the faces with the FaceNet model for training the SVM. Note: this step is not necessary for fine-tuning on a neural classifier

# %%
# Import packages
import os
from os.path import isdir
from os.path import join
import importlib

import numpy as np
import cv2

from src import face_encoders

importlib.reload(face_encoders)
FaceEncoder = face_encoders.FaceEncoder
# Out:
# Using TensorFlow backend.

# %%
encoder_model = FaceEncoder("facenet_keras", "src/encoders/facenet_keras.h5")
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
args = {
    # Set input directory
    # The names of the subdirectories will be the class labels
    "input_dir":"data/faces_dlib/",
    # Set output directory
    # The labels will be subdirectories 
    #     where extracted faces are saved
    "output_dir":"data/embeddings_dlib/",
    "split_types":["train", "val", "test"],
}

# %%
if not os.path.exists(args["output_dir"]):
    os.makedirs(args["output_dir"])

for split in args["split_types"]:
    print(f"[INFO] Encoding faces in {split} set...")
    input_dir = join(args["input_dir"], split)
    subdirs = [subdir for subdir in os.listdir(input_dir) if isdir(join(input_dir,subdir))]
    
    faces = list()
    embeddings = list()
    labels = list()
    for label in subdirs:
        files = os.listdir(join(input_dir, label))
        print(f'    [INFO] Encoding {len(files)} "{label}" faces...')
        for file in files:
            face_path = join(input_dir, label, file)
            face = cv2.imread(face_path)
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face_array = np.asarray(face)
            embedding = encoder_model.get_embedding(face_array)
            faces.append(face_array)
            embeddings.append(embedding)
            labels.append(label)
    faces = np.asarray(faces)
    embeddings = np.asarray(embeddings)
    labels = np.asarray(labels)
    output_face_file = join(args["output_dir"], f"{split}_faces.npz")
    output_emb_file = join(args["output_dir"], f"{split}_embeddings.npz")
    np.savez_compressed(output_face_file, faces, labels)
    np.savez_compressed(output_emb_file, embeddings, labels)
    print(f"[INFO] Saved {split} set as {output_face_file}, shape: {str(embeddings.shape)}, {str(labels.shape)}")
# Out:
# [INFO] Encoding faces in train set...
#     [INFO] Encoding 139 "erik" faces...
#     [INFO] Encoding 97 "diana" faces...
#     [INFO] Encoding 479 "unknown" faces...
# [INFO] Saved train set as data/embeddings_dlib/train_faces.npz, shape: (715, 128), (715,)
# [INFO] Encoding faces in val set...
#     [INFO] Encoding 23 "erik" faces...
#     [INFO] Encoding 98 "diana" faces...
#     [INFO] Encoding 158 "unknown" faces...
# [INFO] Saved val set as data/embeddings_dlib/val_faces.npz, shape: (279, 128), (279,)
# [INFO] Encoding faces in test set...
#     [INFO] Encoding 30 "erik" faces...
#     [INFO] Encoding 33 "diana" faces...
#     [INFO] Encoding 156 "unknown" faces...
# [INFO] Saved test set as data/embeddings_dlib/test_faces.npz, shape: (219, 128), (219,)
